# %% [markdown]
# <!-- import pandas as pd -->
#
# # **Instalación de paquetes**
#
# En este cuaderno de trabajo instalaremos los paquetes necesarios para trabajar con proyectos de ciencia de datos, machine learning y visualizacion de graficos
#
# ![image.png](../assets/kyubey.gif)

# %% [markdown]
# # **Matplotlib**:
#
# Librería de Python usada para crear gráficas y visualizaciones de datos. Permite hacer gráficos de líneas, barras, pastel, dispersión y muchas otras representaciones para analizar información visualmente.

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # **NumPy**
# Numpy es una librería especializada en cálculos numéricos y matemáticos. Facilita el trabajo con arreglos, matrices y operaciones matemáticas rápidas y eficientes.

# %%
# %pip install numpy
# Out:
# Requirement already satisfied: numpy in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (2.4.6)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # **Pandas**
# Librería utilizada para manipular y analizar datos. Permite trabajar con tablas de información, limpiar datos, filtrarlos y organizarlos fácilmente usando estructuras como DataFrames.

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: numpy>=2.3.3 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 4.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pandas
# Successfully installed pandas-3.0.3
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # **Scikit-learn**
# Librería enfocada en machine learning e inteligencia artificial. Se utiliza para entrenar modelos, clasificar datos, realizar predicciones y analizar patrones de manera sencilla.

# %%
# %pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from scikit-learn) (2.4.6)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 2.9 MB/s eta 0:00:00a 0:00:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 6.9 MB/s eta 0:00:0000:0100:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # **Seaborn**
# Librería de visualización basada en Matplotlib. Ayuda a crear gráficas estadísticas más atractivas y fáciles de interpretar con menos código.

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/meme/Documentos/9-IDGS/ExtraccionDB/.venv/lib64/python3.14/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
