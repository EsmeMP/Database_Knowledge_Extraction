# %% [markdown]
# <!-- import pandas as pd -->
#
# # **Instalación de paquetes**
#
# En este cuaderno de trabajo instalaremos los paquetes necesarios para trabajar con proyectos de ciencia de datos, machine learning y visualizacion de graficos
#
# ![image.png](../assets/kyubey.gif)

# %% [markdown]
# # **Matplotlib**:
#
# Librería de Python usada para crear gráficas y visualizaciones de datos. Permite hacer gráficos de líneas, barras, pastel, dispersión y muchas otras representaciones para analizar información visualmente.

# %%
# %pip install matplotlib

# %% [markdown]
# # **NumPy**
# Numpy es una librería especializada en cálculos numéricos y matemáticos. Facilita el trabajo con arreglos, matrices y operaciones matemáticas rápidas y eficientes.

# %%
# %pip install numpy

# %% [markdown]
# # **Pandas**
# Librería utilizada para manipular y analizar datos. Permite trabajar con tablas de información, limpiar datos, filtrarlos y organizarlos fácilmente usando estructuras como DataFrames.

# %%
# %pip install pandas

# %% [markdown]
# # **Scikit-learn**
# Librería enfocada en machine learning e inteligencia artificial. Se utiliza para entrenar modelos, clasificar datos, realizar predicciones y analizar patrones de manera sencilla.

# %%
# %pip install scikit-learn

# %% [markdown]
# # **Seaborn**
# Librería de visualización basada en Matplotlib. Ayuda a crear gráficas estadísticas más atractivas y fáciles de interpretar con menos código.

# %%
# %pip install seaborn

# %%
import pandas as pd

df = pd.read_csv('../data/github_trending_raw_2026.csv')
# print(df.info())
print(df.shape)
print(df.columns)
df.head()
# print(df.isnull().sum())
# Out:
# (1320, 32)
# Index(['rank', 'owner', 'repo_name', 'full_name', 'repo_url', 'description',
#        'language', 'language_filter', 'stars_total_raw', 'forks_total_raw',
#        'stars_period_raw', 'contributor_count_visible', 'period', 'scraped_at',
#        'api_status', 'open_issues', 'watchers', 'subscriber_count',
#        'license_name', 'license_spdx', 'created_at', 'updated_at', 'pushed_at',
#        'topics', 'has_wiki', 'has_projects', 'default_branch', 'size_kb',
#        'homepage', 'is_fork', 'is_archived', 'network_count'],
#       dtype='str')
#    rank      owner        repo_name                 full_name  \
# 0     1  hacksider    Deep-Live-Cam   hacksider/Deep-Live-Cam
# 1     2       obra      superpowers          obra/superpowers
# 2     3   SakanaAI  AI-Scientist-v2  SakanaAI/AI-Scientist-v2
# 3     4    virattt           dexter            virattt/dexter
# 4     5   twentyhq           twenty           twentyhq/twenty
#
#                                       repo_url  \
# 0   https://github.com/hacksider/Deep-Live-Cam
# 1          https://github.com/obra/superpowers
# 2  https://github.com/SakanaAI/AI-Scientist-v2
# 3            https://github.com/virattt/dexter
# 4           https://github.com/twentyhq/twenty
#
#                                          description    language  \
# 0  real time face swap and one-click video deepfa...      Python
# 1  An agentic skills framework & software develop...       Shell
# 2  The AI Scientist-v2: Workshop-Level Automated ...      Python
# 3    An autonomous agent for deep financial research  TypeScript
# 4  Building a modern alternative to Salesforce, p...  TypeScript
#
#   language_filter stars_total_raw forks_total_raw  ...             pushed_at  \
# 0             all          84,522          12,345  ...  2026-03-28T20:54:34Z
# 1             all         121,226           9,836  ...  2026-03-26T00:16:56Z
# 2             all           3,597             542  ...  2025-12-19T07:46:32Z
# 3             all          20,302           2,431  ...  2026-03-26T09:20:31Z
# 4             all          42,511           5,643  ...  2026-03-29T05:37:32Z
#
#                                               topics has_wiki has_projects  \
# 0  ['ai', 'ai-deep-fake', 'ai-face', 'ai-webcam',...     True         True
# 1                                                 []     True         True
# 2                                                 []     True         True
# 3                                                 []     True         True
# 4  ['crm', 'crm-system', 'customer', 'good-first-...    False         True
#
#   default_branch  size_kb                  homepage  is_fork is_archived  \
# 0           main   155987  https://deeplivecam.net/    False       False
# 1           main     2265                       NaN    False       False
# 2           main     4558                       NaN    False       False
# 3           main     1217                       NaN    False       False
# 4           main   889399        https://twenty.com    False       False
#
#   network_count
# 0         12345
# 1          9837
# 2           542
# 3          2431
# 4          5643
#
# [5 rows x 32 columns]
