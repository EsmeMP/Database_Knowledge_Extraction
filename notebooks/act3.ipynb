# %%
import pandas as pd
filename = '../data/ml_git_users.csv'

data = pd.read_csv(filename)

print(data.shape)
print(data.info)
# data.describe()
data.head()
# Out:
# (670, 12)
# <bound method DataFrame.info of      Unnamed: 0          login        id  \
# 0             0  Gift-Ojeabulu  45846624
# 1             1      korecodes  15997058
# 2             2    jerryOkafor  12306753
# 3             3          cydal  11761529
# 4             4        adefemi  12401108
# ..          ...            ...       ...
# 665         665       AimeM250  81082709
# 666         666  mattrwiyereka  44134912
# 667         667     datagatoni  47833633
# 668         668       Mwenda01  30906383
# 669         669         coekoh  73580470
#
#                                             url                name  \
# 0    https://api.github.com/users/Gift-Ojeabulu        GiftOjeabulu
# 1        https://api.github.com/users/korecodes     Daniel Apantaku
# 2      https://api.github.com/users/jerryOkafor  Jerry Hanks Okafor
# 3            https://api.github.com/users/cydal    Sijuade Oguntayo
# 4          https://api.github.com/users/adefemi       Adefemi Oseni
# ...

# %%
#  NOMBRE -> ml_git_users
# TIPO -> Clasificacion Multiclase
# DIMENSIONES -> 670 filas y 12 columnas
# ENTRADAS = (unnamed) = numericas, login = texto, id = numericas, url = texto, name = texto, company = texto, blog = texto, location = texto,  email = texto, bio = texto, followers = numerica, following = numerica 
# RESULTADO = Nominal -> Nominal carece de orden, no se pueden realizar operaciones matematicas, se pueden realizar conteos de frecuencia, se pueden realizar graficas de barras, graficas circulares, etc.
